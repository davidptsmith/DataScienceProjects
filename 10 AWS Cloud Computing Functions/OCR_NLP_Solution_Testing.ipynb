# %% [markdown]
# # Week 9 More AI
#
# ## Note:

# %% [markdown]
# # Import Python Libraries

# %%
import os
import boto3
from botocore.exceptions import ClientError

# %% [markdown]
# # Rekognition: Labels, Faces, Text

# %%
import boto3
client = boto3.client('rekognition', "ap-southeast-2")

def detect_image(photo_name , bucket_name):
    response = client.detect_labels(
        Image={
            'S3Object': {
                "Bucket" : bucket_name, 
                "Name": photo_name
            }
        })
    print()
    res = response["Labels"][0]
    name = res["Name"]
    confidence = str( round( ( res["Confidence"] * 1) , 1 ) ) + "%" 
    print(f"Name: {name} : Confidence: {confidence}")

def detect_faces(photo_name , bucket_name):
    response = client.detect_faces(
        Image={
        'S3Object': {
                    "Bucket" : bucket_name, 
                    "Name": photo_name
                }
        })
    
    print()
    print("Face Details: ")
    res = response["FaceDetails"]
    print(res)
    # name = res["Name"]
    # confidence = str( round( ( res["Confidence"] * 1) , 1 ) ) + "%" 
    # print(f"Name: {name} : Confidence: {confidence}")

def detect_text(photo_name , bucket_npoame):
    response = client.detect_text(
        Image={
        'S3Object': {
                    "Bucket" : bucket_name, 
                    "Name": photo_name
                }
        })
    res = response["TextDetections"]

    print()
    print("Detected Words: ")
    for r in res: 
       print( r["DetectedText"] , end=" ")
    print()
    print()
    print()
    print("Response")
    print(res)

bucket_name = "21484971-cloudstorage"

## Image Names
text = "Test2.jpg"

## Extract Text
detect_text(text , bucket_name)

# ## Detect Image Labels 
# detect_image(urban , bucket_name)
# detect_image(beach , bucket_name)

# ## Detect Faces
# detect_faces(person , bucket_name)
# Out:
# Detected Words:
# 254 255 TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTO TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTH Left hand side. Gallop Chas, W Russell street, Loaderville Marshall Thos Barrack st intersects Rox Braser- continued. Dawson & Co. Stewart, jewellers .. Off Cambridge 85. Wardrop s Victoria Hall COMMERCIAL McCunker Bernard BANK OF AUS. 324 Alliambra Café here is Nicholson ril Right hand side. Tigha Michael TRALIA LTD. (THE) (Herbert 326 Pasridge Fred J.H Vincent J. tea rooms Hill Arthur T. fruiterer Ledlie Heron, Osborne 328 Alfred Stone Left hand side general Clarke & Knapp, opticians man- Welx Julius Grieve Miss Jane R. dressmkr Stacey Hary. P 330 Rowe Joseph 254 255 TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTO TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTH Left hand side. Gallop Chas, W Russell street, Loaderville Marshall Thos Barrack st intersects Rox Braser- continued. Dawson & Co. Stewart, jewellers .. Off Cambridge 85. Wardrop s Victoria Hall COMMERCIAL McCunker Bernard BANK OF AUS. 324 Alliambra Café here is Nicholson ril Right hand side. Tigha Michael TRALIA LTD. (THE) (Herbert 326 Pasridge Fred J.H Vincent J. tea rooms Hill Arthur T. fruiterer Ledlie Heron, Osborne 328 Alfred Stone Left hand side general Clarke & Knapp, opticians man- Welx Julius Grieve Miss Jane R. dressmkr Stacey Hary. P 330 Rowe Joseph
913947343826}, 'Polygon': [{'X': 0.9433028697967529, 'Y': 0.05338913947343826}, {'X': 0.971689760684967, 'Y': 0.0544300377368927}, {'X': 0.9713131189346313, 'Y': 0.06470268964767456}, {'X': 0.9429262280464172, 'Y': 0.06366179138422012}]}}, {'DetectedText': 'Left hand side.', 'Type': 'LINE', 'Id': 6, 'Confidence': 81.98725891113281, 'Geometry': {'BoundingBox': {'Width': 0.058716803789138794, 'Height': 0.0126953125, 'Left': 0.5886545777320862, 'Top': 0.06640625}, 'Polygon': [{'X': 0.5886545777320862, 'Y': 0.06640625}, {'X': 0.6473713517189026, 'Y': 0.06640625}, {'X': 0.6473713517189026, 'Y': 0.0791015625}, {'X': 0.5886545777320862, 'Y': 0.0791015625}]}}, {'DetectedText': 'Gallop Chas, W', 'Type': 'LINE', 'Id': 7, 'Confidence': 73.8929214477539, 'Geometry': {'BoundingBox': {'Width': 0.06466280668973923, 'Height': 0.0126953125, 'Left': 0.32851681113243103, 'Top': 0.068359375}, 'Polygon': [{'X': 0.32851681113243103, 'Y': 0.068359375}, {'X': 0.39317962527275085, 'Y': 0.068359375}, {'X': 0.39317962527275085, 'Y': 0.0810546875}, {'X': 0.32851681113243103, 'Y': 0.0810546875}]}}, {'DetectedText': 'Russell street, Loaderville', 'Type': 'LINE', 'Id': 8, 'Confidence': 67.91622161865234, 'Geometry': {'BoundingBox': {'Width': 0.11190599203109741, 'Height': 0.014877566136419773, 'Left': 0.7058583498001099, 'Top': 0.0687447190284729}, 'Polygon': [{'X': 0.706121027469635, 'Y': 0.0687447190284729}, {'X': 0.8177643418312073, 'Y': 0.07108330726623535}, {'X': 0.8175016641616821, 'Y': 0.0836222842335701}, {'X': 0.7058583498001099, 'Y': 0.08128368854522705}]}} ...

# %% [markdown]
# ## Functions

# %%
import boto3
client = boto3.client('comprehend')

def detect_language(text):
    # Detect Entities
    response = client.detect_dominant_language(
        Text=text,
    )

    res = response['Languages']

    languages_dic = {
    "de ": "German",
    "en":"English",
    "es":"Spanish",
    "it":"Italian",
    "pt":"Portuguese",
    "fr":"French",
    "ja":"Japanese",
    "ko":"Korean",
    "hi":"Hindi",
    "ar":"Arabic",
    "zh":"Chinese (simplified)",
    "zh-TW":"Chinese (traditional)"
    }

    for p in res:
            code = p['LanguageCode']
            langage = languages_dic.get( code)
            confidence = str( round( ( p['Score'] * 100) , 1 ) ) + "%"

    print("Output:")
    print(f'{langage} detected with {confidence} confidence.')
    return(code)

def detect_sentiment(text , code):
    response = client.detect_sentiment(Text=text, LanguageCode=code )
    sentiment = response['Sentiment'].capitalize()
    score_res = response['SentimentScore']
    confidence = str( round( ( score_res[sentiment]  * 100) , 1 ) ) + "%"
    print(f'Sentiment: {sentiment}, Score: {confidence} ')

def detect_entities(text, code):
    response = client.detect_entities(
    Text=text,
    LanguageCode=code)
    res = response['Entities']
    print("Entities: ")
    for r in res:
        txt = r["Text"]
        txt_type = r["Type"]
        confidence = str( round( ( r["Score"]  * 100) , 1 ) ) + "%"
        print(f"Text: {txt}, Type: {txt_type} Score: {confidence}")

def detect_keyphrase(text, code):
    response = client.detect_key_phrases(
    Text=text,
    LanguageCode=code)
    print("Key Phrases: ")
    res = response['KeyPhrases']
    for r in res:
        txt = r["Text"]
        confidence = str( round( ( r["Score"]  * 100) , 1 ) ) + "%"
        print(f"Text: {txt}, Score: {confidence}")

def detect_syntax(text, code):
    response = client.detect_syntax(
    Text=text,
    LanguageCode=code)
    res = response['SyntaxTokens']
    print("Syntax Tokens: ")
    for r in res:
        txt = r["Text"]
        part_of_speech = r["PartOfSpeech"]
        tag =  part_of_speech["Tag"] 
        confidence = str( round( ( part_of_speech["Score"]  * 100) , 1 ) ) + "%"
        print(f"Text: {txt}, Part Tag: {tag} , score: {confidence}")

def run_detect_functions(text, code):
    # code = detect_language(text)
    # detect_sentiment(text , code)
    detect_entities(text, code)
    detect_keyphrase(text, code)
    # detect_syntax(text, code)

# %% [markdown]
# # Detect Languages, Sentiment, Entities, Key Phrases, Syntax
#
# ## What are Entities
# They are a reference to a real world object such as people, places, things, and measurements. (pretty hard to get more concise than the aws definition)
#
# For future reference, categories:
#
# COMMERCIAL_ITEM
# A branded product
#
# DATE
# A full date (for example, 11/25/2017), day (Tuesday), month (May), or time (8:30 a.m.)
#
# EVENT
# An event, such as a festival, concert, election, etc.
#
# LOCATION
# A specific location, such as a country, city, lake, building, etc.
#
# ORGANIZATION
# Large organizations, such as a government, company, religion, sports team, etc.
#
# OTHER
# Entities that don't fit into any of the other entity categories
#
# PERSON
# Individuals, groups of people, nicknames, fictional characters
#
# QUANTITY
# A quantified amount, such as currency, percentages, numbers, bytes, etc.
#
# TITLE
# An official name given to any creation or creative work, such as movies, books, songs, etc.
#
# ## What are Key Phrases
# Is a portion of text containing a noun and a descriptor.
#
# ## What is Syntax
# It is labeling what each part of the text is with regards to its grammatical construct. i.e noun, adjective.

# %%
text = '254 255 TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTO TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTH Left hand side. Gallop Chas, W Russell street, Loaderville Marshall Thos Barrack st intersects Rox Braser- continued. Dawson & Co. Stewart, jewellers .. Off Cambridge 85. Wardrop s Victoria Hall COMMERCIAL McCunker Bernard BANK OF AUS. 324 Alliambra Café here is Nicholson ril Right hand side. Tigha Michael TRALIA LTD. (THE) (Herbert 326 Pasridge Fred J.H Vincent J. tea rooms Hill Arthur T. fruiterer Ledlie Heron, Osborne 328 Alfred Stone Left hand side general Clarke & Knapp, opticians man- Welx Julius Grieve Miss Jane R. dressmkr Stacey Hary. P 330 Rowe Joseph 254 255 TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTO TOWNS-W. AUSTRALIA DIRECTORY-TOWNS. PERTH Left hand side. Gallop Chas, W Russell street, Loaderville
# Text: Osborne 328 Alfred Stone, Score: 89.1%
# Text: hand side general Clarke & Knapp, Score: 89.9%
# Text: opticians man, Score: 93.2%
# Text: Welx Julius Grieve Miss Jane R. dressmkr Stacey Hary, Score: 92.6%
# Text: P 330 Rowe Joseph 254, Score: 92.8%
# Text: AUSTRALIA DIRECTORY, Score: 98.4%
# Text: TOWNS, Score: 66.5%
# Text: PERTO TOWNS, Score: 98.3%
# Text: AUSTRALIA DIRECTORY, Score: 98.7%
# Text: TOWNS, Score: 57.8%
# Text: PERTH, Score: 97.4%
# Text: hand side, Score: 74.5%
# Text: Gallop Chas, Score: 96.5%
# Text: W Russell street, Score: 98.3%
# Text: Loaderville Marshall Thos Barrack st intersects Rox Braser, Score: 84.9%
# Text: Dawson & Co. Stewart, Score: 98.2%
# Text: jewellers, Score: 94.3%
# Text: Cambridge 85, Score: 75.0%
# Text: Wardrop, Score: 94.0%
# Text: Victoria Hall COMMERCIAL McCunker Bernard BANK, Score: 98.4%
# Text: AUS, Score: 98.8%
# Text: 324 Alliambra Café, Score: 98.7%
# Text: Nicholson ril Right hand side, Score: 71.9%
# Text: Tigha Michael TRALIA LTD., Score: 91.3%
# Text: Herbert 326 Pasridge Fred J.H Vincent J. tea rooms Hill Arthur T. fruiterer Ledlie Heron, Score: 85.3%
# Text: Osborne 328 Alfred Stone, Score: 89.7%
# Text: hand side general Clarke & Knapp, Score: 83.1%
# Text: opticians man, Score: 92.8%
# Text: Welx Julius Grieve Miss Jane R. dressmkr Stacey Hary, Score: 92.3%

# %%
text = "El Quijote es la obra más conocida de Miguel de Cervantes Saavedra. Publicada su primera parte con el título de El ingenioso hidalgo don Quijote de la Mancha a comienzos de 1605, es una de las obras más destacadas de la literatura española y la literatura universal, y una de las más traducidas. En 1615 aparecería la segunda parte del Quijote de Cervantes con el título de El ingenioso caballero don Quijote de la Mancha."

run_detect_functions(text)
# Out:
# Output:
# Spanish detected with 99.8% confidence.
# Sentiment: Neutral, Score: 83.8%
# Entities:
# Text: El Quijote, Type: TITLE Score: 97.1%
# Text: Miguel de Cervantes Saavedra, Type: PERSON Score: 99.9%
# Text: primera parte, Type: QUANTITY Score: 89.3%
# Text: El ingenioso hidalgo don Quijote de la Mancha, Type: TITLE Score: 97.7%
# Text: 1605, Type: DATE Score: 76.6%
# Text: una, Type: QUANTITY Score: 67.7%
# Text: española, Type: OTHER Score: 98.3%
# Text: una de las más, Type: QUANTITY Score: 64.4%
# Text: 1615, Type: DATE Score: 98.2%
# Text: segunda parte, Type: QUANTITY Score: 90.4%
# Text: Quijote de Cervantes, Type: TITLE Score: 90.2%
# Text: El ingenioso caballero don Quijote de la Mancha, Type: TITLE Score: 98.9%
# Key Phrases:
# Text: El Quijote, Score: 99.9%
# Text: la obra, Score: 100.0%
# Text: más conocida, Score: 99.9%
# Text: Miguel de Cervantes Saavedra, Score: 100.0%
# Text: su primera parte, Score: 100.0%
# Text: el título, Score: 100.0%
# Text: El ingenioso hidalgo don Quijote de la Mancha, Score: 95.6%
# Text: comienzos, Score: 100.0%
# Text: 1605, Score: 99.6%
# Text: las obras, Score: 100.0%
# Text: más destacadas, Score: 100.0%
# Text: la literatura española, Score: 100.0%
# Text: la literatura universal, Score: 100.0%
# Text: las más traducidas, Score: 100.0%
# Text: la segunda parte, Score: 100.0%
# Text: Quijote de Cervantes, Score: 100.0%
# Text: el título, Score: 100.0%
# Text: ingenioso caballero don Quijote de la Mancha, Score: 93.6%
# Syntax Tokens:
# Text: El, Part Tag: DET , score: 100.0%
# Text: Quijote, Part Tag: PROPN , score: 52.6%
# Text: es, Part Tag: VERB , score: 100.0%
# Text: la, Part Tag: DET , score: 100.0%
# Text: obra, Part Tag: NOUN , score: 99.9%
# Text: más, Part Tag: ADV , score: 100.0%
# Text: conocida, Part Tag: ADJ , score: 82.6%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: Miguel, Part Tag: PROPN , score: 98.1%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: Cervantes, Part Tag: PROPN , score: 99.5%
# Text: Saavedra, Part Tag: PROPN , score: 100.0%
# Text: ., Part Tag: PUNCT , score: 100.0%
# Text: Publicada, Part Tag: VERB , score: 99.9%
# Text: su, Part Tag: DET , score: 100.0%
# Text: primera, Part Tag: ADJ , score: 100.0%
# Text: parte, Part Tag: NOUN , score: 100.0%
# Text: con, Part Tag: ADP , score: 100.0%
# Text: el, Part Tag: DET , score: 100.0%
# Text: título, Part Tag: NOUN , score: 99.7%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: El, Part Tag: DET , score: 100.0%
# Text: ingenioso, Part Tag: ADJ , score: 60.5%
# Text: hidalgo, Part Tag: NOUN , score: 87.4%
# Text: don, Part Tag: PROPN , score: 48.6%
# Text: Quijote, Part Tag: PROPN , score: 97.2%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: la, Part Tag: DET , score: 99.9%
# Text: Mancha, Part Tag: PROPN , score: 96.0%
# Text: a, Part Tag: ADP , score: 100.0%
# Text: comienzos, Part Tag: PROPN , score: 50.2%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: 1605, Part Tag: NUM , score: 100.0%
# Text: ,, Part Tag: PUNCT , score: 100.0%
# Text: es, Part Tag: VERB , score: 100.0%
# Text: una, Part Tag: PRON , score: 99.9%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: las, Part Tag: DET , score: 100.0%
# Text: obras, Part Tag: NOUN , score: 100.0%
# Text: más, Part Tag: ADV , score: 100.0%
# Text: destacadas, Part Tag: ADJ , score: 96.7%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: la, Part Tag: DET , score: 100.0%
# Text: literatura, Part Tag: NOUN , score: 99.8%
# Text: española, Part Tag: ADJ , score: 100.0%
# Text: y, Part Tag: CCONJ , score: 100.0%
# Text: la, Part Tag: DET , score: 100.0%
# Text: literatura, Part Tag: NOUN , score: 100.0%
# Text: universal, Part Tag: ADJ , score: 100.0%
# Text: ,, Part Tag: PUNCT , score: 100.0%
# Text: y, Part Tag: CCONJ , score: 100.0%
# Text: una, Part Tag: PRON , score: 99.5%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: las, Part Tag: DET , score: 93.6%
# Text: más, Part Tag: ADV , score: 100.0%
# Text: traducidas, Part Tag: ADJ , score: 77.0%
# Text: ., Part Tag: PUNCT , score: 100.0%
# Text: En, Part Tag: ADP , score: 100.0%
# Text: 1615, Part Tag: NUM , score: 100.0%
# Text: aparecería, Part Tag: VERB , score: 100.0%
# Text: la, Part Tag: DET , score: 100.0%
# Text: segunda, Part Tag: ADJ , score: 100.0%
# Text: parte, Part Tag: NOUN , score: 100.0%
# Text: del, Part Tag: ADP , score: 100.0%
# Text: Quijote, Part Tag: PROPN , score: 70.2%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: Cervantes, Part Tag: PROPN , score: 99.1%
# Text: con, Part Tag: ADP , score: 100.0%
# Text: el, Part Tag: DET , score: 100.0%
# Text: título, Part Tag: NOUN , score: 99.5%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: El, Part Tag: DET , score: 100.0%
# Text: ingenioso, Part Tag: ADJ , score: 68.4%
# Text: caballero, Part Tag: NOUN , score: 91.2%
# Text: don, Part Tag: PROPN , score: 74.0%
# Text: Quijote, Part Tag: PROPN , score: 98.0%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: la, Part Tag: DET , score: 100.0%
# Text: Mancha, Part Tag: PROPN , score: 98.0%
# Text: ., Part Tag: PUNCT , score: 100.0%

# %%
text = "Moi je n'étais rien Et voilà qu'aujourd'hui Je suis le gardien Du sommeil de ses nuits Je l'aime à mourir Vous pouvez détruire Tout ce qu'il vous plaira Elle n'a qu'à ouvrir L'espace de ses bras Pour tout reconstruire Pour tout reconstruire Je l'aime à mourir"

run_detect_functions(text)
# Out:
# Output:
# French detected with 99.8% confidence.
# Sentiment: Negative, Score: 59.2%
# Entities:
# Text: aujourd'hui, Type: DATE Score: 96.6%
# Text: Tout ce qu', Type: QUANTITY Score: 65.2%
# Key Phrases:
# Text: Moi, Score: 100.0%
# Text: je, Score: 95.5%
# Text: n'étais rien, Score: 95.6%
# Text: aujourd'hui, Score: 94.9%
# Text: Je suis le gardien Du sommeil de ses nuits, Score: 94.1%
# Text: Je, Score: 100.0%
# Text: l', Score: 100.0%
# Text: Vous, Score: 99.9%
# Text: Tout ce, Score: 98.3%
# Text: qu', Score: 96.5%
# Text: il, Score: 99.9%
# Text: vous, Score: 100.0%
# Text: Elle, Score: 100.0%
# Text: L'espace de ses bras, Score: 99.5%
# Text: tout, Score: 89.3%
# Text: tout, Score: 96.2%
# Text: Je, Score: 100.0%
# Text: l', Score: 100.0%
# Syntax Tokens:
# Text: Moi, Part Tag: PRON , score: 98.9%
# Text: je, Part Tag: PRON , score: 100.0%
# Text: n', Part Tag: ADV , score: 94.2%
# Text: étais, Part Tag: AUX , score: 95.4%
# Text: rien, Part Tag: PRON , score: 95.2%
# Text: Et, Part Tag: CCONJ , score: 100.0%
# Text: voilà, Part Tag: VERB , score: 100.0%
# Text: qu', Part Tag: SCONJ , score: 64.1%
# Text: aujourd'hui, Part Tag: ADV , score: 100.0%
# Text: Je, Part Tag: PRON , score: 100.0%
# Text: suis, Part Tag: AUX , score: 89.3%
# Text: le, Part Tag: DET , score: 100.0%
# Text: gardien, Part Tag: NOUN , score: 99.9%
# Text: Du, Part Tag: ADP , score: 74.3%
# Text: sommeil, Part Tag: NOUN , score: 99.9%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: ses, Part Tag: DET , score: 100.0%
# Text: nuits, Part Tag: NOUN , score: 99.9%
# Text: Je, Part Tag: PRON , score: 100.0%
# Text: l', Part Tag: PRON , score: 99.8%
# Text: aime, Part Tag: VERB , score: 100.0%
# Text: à, Part Tag: ADP , score: 100.0%
# Text: mourir, Part Tag: VERB , score: 100.0%
# Text: Vous, Part Tag: PRON , score: 99.0%
# Text: pouvez, Part Tag: AUX , score: 60.1%
# Text: détruire, Part Tag: VERB , score: 100.0%
# Text: Tout, Part Tag: DET , score: 94.4%
# Text: ce, Part Tag: PRON , score: 99.5%
# Text: qu', Part Tag: PRON , score: 93.1%
# Text: il, Part Tag: PRON , score: 100.0%
# Text: vous, Part Tag: PRON , score: 100.0%
# Text: plaira, Part Tag: VERB , score: 100.0%
# Text: Elle, Part Tag: PRON , score: 99.6%
# Text: n', Part Tag: ADV , score: 94.5%
# Text: a, Part Tag: VERB , score: 99.4%
# Text: qu', Part Tag: ADV , score: 87.1%
# Text: à, Part Tag: ADP , score: 100.0%
# Text: ouvrir, Part Tag: VERB , score: 100.0%
# Text: L', Part Tag: DET , score: 79.4%
# Text: espace, Part Tag: NOUN , score: 99.8%
# Text: de, Part Tag: ADP , score: 100.0%
# Text: ses, Part Tag: DET , score: 100.0%
# Text: bras, Part Tag: NOUN , score: 99.9%
# Text: Pour, Part Tag: ADP , score: 98.5%
# Text: tout, Part Tag: PRON , score: 95.0%
# Text: reconstruire, Part Tag: VERB , score: 100.0%
# Text: Pour, Part Tag: ADP , score: 99.3%
# Text: tout, Part Tag: PRON , score: 95.0%
# Text: reconstruire, Part Tag: VERB , score: 100.0%
# Text: Je, Part Tag: PRON , score: 99.2%
# Text: l', Part Tag: PRON , score: 99.5%
# Text: aime, Part Tag: VERB , score: 100.0%
# Text: à, Part Tag: ADP , score: 100.0%
# Text: mourir, Part Tag: VERB , score: 100.0%

# %%
text = "L'amor che move il sole e l'altre stelle."

run_detect_functions(text)
# Out:
# Output:
# Italian detected with 99.3% confidence.
# Sentiment: Positive, Score: 98.5%
# Entities:
# Key Phrases:
# Text: L'amor, Score: 100.0%
# Text: che, Score: 100.0%
# Text: il sole, Score: 100.0%
# Text: l'altre stelle, Score: 100.0%
# Syntax Tokens:
# Text: L', Part Tag: DET , score: 99.9%
# Text: amor, Part Tag: NOUN , score: 99.1%
# Text: che, Part Tag: PRON , score: 99.5%
# Text: move, Part Tag: VERB , score: 99.7%
# Text: il, Part Tag: DET , score: 100.0%
# Text: sole, Part Tag: NOUN , score: 99.7%
# Text: e, Part Tag: CCONJ , score: 100.0%
# Text: l', Part Tag: DET , score: 100.0%
# Text: altre, Part Tag: ADJ , score: 68.3%
# Text: stelle, Part Tag: NOUN , score: 99.4%
# Text: ., Part Tag: PUNCT , score: 100.0%
